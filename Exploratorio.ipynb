# %% [markdown]
# <a href="https://colab.research.google.com/github/janicasaic2/ml1/blob/mapu/Exploratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
from google.colab import files
import os
import pandas as pd

# %%
files.upload()  # Selecciona el archivo kaggle.json para subirlo
# Out:
#      <input type="file" id="files-24923ad0-13c6-4170-9348-c87445d756f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24923ad0-13c6-4170-9348-c87445d756f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
os.makedirs('/root/.kaggle', exist_ok=True)
# !mv kaggle.json /root/.kaggle/

# %%
# !pip install kaggle

# %%
# !kaggle competitions download -c machine-learning-pregrado-2025

# %%
# !unzip machine-learning-pregrado-2025.zip
# Out:
# Archive:  machine-learning-pregrado-2025.zip
#   inflating: Datos Taller individual - 2410 (Estudiantes).xlsx
#   inflating: test.csv
#   inflating: train.csv

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    idloc  edadloc  correo  paginas  telefono   impresa  servicio  nomina  \
# 0   1648       11   10042       68        35  22609.49        30   66307
# 1   1259        3   11909      107        42  24561.99        35   29107
# 2    674       13   10669       75        33  38914.22        52    9519
# 3   1558        7    6981       65        19  39204.97        30   28651
# 4   1626       22   10940       74        37  23947.08        46   30654
#
#    idmercado tamamer  promo    ropamujer
# 0          8  Grande      2  43747.69227
# 1          8  Grande      2  37483.68999
# 2          4  Median      3  57522.99548
# 3          7  Grande      1  50338.06208
# 4          7  Grande      2  45675.55005
